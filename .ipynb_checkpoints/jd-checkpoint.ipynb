# %%
import pandas as pd
from pandas import DataFrame
from bs4 import BeautifulSoup
import requests
import json
import re
from multiprocessing.dummy import Pool
import random
import time
import math
from lxml import etree

# %%
#搜索页面
init_search = 'https://coll.jd.com/list.html?sub={}&sort=sort_totalsales15_desc&stock=0&page='

#商品页面
init_itemUrl = 'https://item.jd.com/{}.html'

headers={
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'zh-CN,zh;q=0.9',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36'
        }

init_commentUrl = 'https://sclub.jd.com/comment/productPageComments.action?productId={}&score=0&sortType=5&page={}&pageSize=10&isShadowSku=0&fold=1'
init_priceUrl = 'https://p.3.cn/prices/mgets?skuIds=J_{}'

# %% [markdown]
# target = {'行车记录仪': '23931'}

# %%
def getitemUrl(target,maxpage = 1):
    itemList = []
    for i in range(1,maxpage+1):
        url = init_search.format(target)  + str(i)
        res = requests.get(url,headers=headers)
        selector = etree.HTML(res.text)
        itemList.extend(selector.xpath('//div[@id="plist"]/ul/li/div/div[@class="p-name"]/a/@href'))
    return itemList

# %%
def getitemidList(target,maxpage = 1):
    itemList = []
    itemidList = []
    for i in range(1,maxpage+1):
        url = init_search.format(target)  + str(i)
        res = requests.get(url,headers=headers)
        selector = etree.HTML(res.text)
        itemList.extend(selector.xpath('//div[@id="plist"]/ul/li/div/div[@class="p-name"]/a/@href'))
        
    print('页面获取完成，共有%d页%d个商品'%(maxpage,len(itemList)))
    i = 1
    for itemUrl in itemList:
        res = requests.get('https:'+itemUrl,headers=headers).text
        selector = etree.HTML(res)
        itemidList.extend(selector.xpath('//div[@id="choose-attrs"]/div//div[@class="dd"]/div/@data-sku')) 
        print('\r' + str(i) + '/' + str(len(itemList)),end = '')
        i += 1
    print('所有分类商品获取完成，共有%d个商品'%(len(itemidList)))
    return itemidList

# %%
itemidList = getitemidList(target['行车记录仪'],maxpage=1)
# Out:
# 页面获取完成，共有1页60个商品
# 60/60所有分类商品获取完成，共有226个商品

# %%
def getitemInfo(itemid):
    itemUrl = init_itemUrl.format(itemid)
    res = openlink(itemUrl)
    selector = etree.HTML(res.text)

    title = "".join(selector.xpath(
                    '//div[@class="sku-name"]/text()')).replace(' ', '').replace('\r', '').replace('\n', '')

    itemDetail = ";".join(selector.xpath('//div[@class="p-parameter"]/ul[@class="parameter2 p-parameter-list"]/li/text()'))

    content = json.loads(requests.get(init_priceUrl.format(itemid)).text)
    price = content[0]['p']

    comment = json.loads(requests.get(init_commentUrl.format(itemid,0)).text)
    goodRate = comment['productCommentSummary']['goodRate']
    commentCount= comment['productCommentSummary']['commentCountStr']
    itemInfo = pd.DataFrame(dict(itemUrl = [itemUrl],
                                itemid = [itemid],
                                title = [title],
                                itemDetail = [itemDetail],
                                price = [price],
                                goodRate = [goodRate],
                                commentCount = [commentCount]),
                                columns=['itemid',
                                            'itemUrl',
                                            'title',
                                            'itemDetail',
                                            'price' ,
                                            'goodRate',
                                            'commentCount'])
    print('#',end = '')
    return itemInfo

# %%
def getitemComment(itemid):
    itemUrl = init_itemUrl.format(itemid)
    res = openlink(init_commentUrl.format(itemid,0))
    jc = json.loads(res.text)
    maxPage = jc['maxPage']
    eachComment = []
    for page in range(0,maxPage):
        res = openlink(init_commentUrl.format(itemid,page))
        jc = json.loads(res.text)
        if 'comments' in jc:
            commentlist = jc['comments']
            for comment in commentlist:
                nickname = comment['nickname']
                if 'productColor' in comment:
                    productColor  = comment['productColor']
                else :
                    productColor = None
                score = comment['score']
                content = comment['content']
                creationTime = comment['creationTime']
                if 'afterUserComment' in comment:
                    afterUserComment = comment['afterUserComment']['hAfterUserComment']['content']
                    afterDays = comment['afterUserComment']['created']
                else :
                    afterUserComment= None
                    afterDays= None
                eachComment.append(pd.DataFrame(dict(itemid = [itemid],
                                                      itemUrl = [itemUrl],
                                                      nickname = [nickname],
                                                      productColor = [productColor],
                                                      score = [score],
                                                      content = [content],
                                                      creationTime = [creationTime],
                                                      afterUserComment = [afterUserComment],
                                                      afterDays = [afterDays])))
            else :
                print('被干')
        print('\r' + str(page) + '/' + str(maxPage-1),end = '')
    itemComment = pd.concat(eachComment,ignore_index=True)
    return itemComment

# %%
def openlink(link):
    maxTryNum = 10
    for tries in range(0,maxTryNum):
        try:
            res = requests.get(link, headers = headers)
            return res
        except:
            if tries < (maxTryNum - 1):
                print("啊呀")
                continue
            else:
                print("Has tried %d times to access url %s, all failed!", maxNum, link)
                break

# %% [markdown]
# ## 测试代码

# %%
target = 23931
itemidList = getitemidList(target,1)
# Out:
# 页面获取完成，共有1页60个商品
# 60/60所有分类商品获取完成，共有226个商品

# %% [markdown]
# ### 并行爬取商品信息

# %%
pool = Pool(8)
time1 =time.time()
itemInfo = pool.map(getitemInfo,itemidList)
pool.close()
pool.join()
time2 =time.time()
print(str(time2-time1))
# Out:
# ##################################################################################################################################################################################################################################25.985722303390503

# %%
pd.concat(itemInfo,ignore_index=True)
# Out:
#           itemid                               itemUrl  \
# 0        5535583      https://item.jd.com/5535583.html
# 1        8035395      https://item.jd.com/8035395.html
# 2        7131530      https://item.jd.com/7131530.html
# 3        7176918      https://item.jd.com/7176918.html
# 4        5018268      https://item.jd.com/5018268.html
# 5        7390537      https://item.jd.com/7390537.html
# 6        7345529      https://item.jd.com/7345529.html
# 7        2743207      https://item.jd.com/2743207.html
# 8        3527963      https://item.jd.com/3527963.html
# 9        3200346      https://item.jd.com/3200346.html
# 10       2131644      https://item.jd.com/2131644.html
# 11       2982126      https://item.jd.com/2982126.html
# 12       3200316      https://item.jd.com/3200316.html
# 13       7897905      https://item.jd.com/7897905.html
# 14       8246803      https://item.jd.com/8246803.html
# 15       8033080      https://item.jd.com/8033080.html
# 16       8035688      https://item.jd.com/8035688.html
# 17       8035166      https://item.jd.com/8035166.html
# 18       3527967      https://item.jd.com/3527967.html
# 19       3527891      https://item.jd.com/3527891.html
# 20       7188740      https://item.jd.com/7188740.html
# 21       5724670      https://item.jd.com/5724670.html
# 22       4126205      https://item.jd.com/4126205.html
# 23       8247774      https://item.jd.com/8247774.html
# 24       8692389      https://item.jd.com/8692389.html
# 25       8479254      https://item.jd.com/8479254.html
# 26       8692391      https://item.jd.com/8692391.html
# 27       8692393      https://item.jd.com/8692393.html
# 213  商品名称：执法先锋 PD50 1296P高清红外夜视专业执法记录仪现场记录器 快充版32G;...   580.00      1.00
# 214  商品名称：执法先锋 PD50 1296P高清红外夜视专业执法记录仪现场记录器 快充版64G;...   680.00      1.00
# 215  商品名称：执法先锋 PD50 1296P高清红外夜视专业执法记录仪现场记录器 快充版128G...  1080.00      1.00
# 216  商品名称：执法先锋 PD50 1296P高清红外夜视专业执法记录仪现场记录器 GPS版16G...   580.00      1.00
# 217  商品名称：执法先锋 PD50 1296P高清红外夜视专业执法记录仪现场记录器 GPS版32G...   680.00      1.00
# 218  商品名称：执法先锋 PD50 1296P高清红外夜视专业执法记录仪现场记录器 GPS版64G...   780.00      1.00
# 219  商品名称：执法先锋 PD50 1296P高清红外夜视专业执法记录仪现场记录器 GPS版128...  1180.00      1.00
# 220  商品名称：执法先锋 PD50 1296P高清红外夜视专业执法记录仪现场记录器 WiFi版16...   580.00      1.00
# 221  商品名称：执法先锋 PD50 1296P高清红外夜视专业执法记录仪现场记录器 WiFi版32...   680.00      1.00
# 222  商品名称：执法先锋 PD50 1296P高清红外夜视专业执法记录仪现场记录器 WiFi版64...   780.00      1.00
# 223  商品名称：执法先锋 PD50 1296P高清红外夜视专业执法记录仪现场记录器 WiFi版12...  1180.00      1.00
# 224  商品名称：群华D2;商品编号：4845026;商品毛重：400.00g;商品产地：中国大陆;...   499.00      0.99
# 225  商品名称：群华D2;商品编号：6004749;商品毛重：439.00g;商品产地：中国大陆;...   699.00      0.99
#
#     commentCount
# 0           15万+
# 1           11万+
# 2           15万+
# 3           15万+
# 4           13万+
# 5           13万+
# 6           13万+
# 7           13万+
# 8           13万+
# 9           13万+
# 10          13万+
# 11          13万+
# 12          13万+
# 13         2500+
# 14         2400+
# 15         2400+
# 16         2400+
# 17         2400+
# 18          17万+
# 19          17万+
# 20          10万+
# 21         1.9万+
# 22         1.9万+
# 23         1.9万+
# 24          500+
# 25          500+
# 26          500+
# 27          500+
# 28         1.3万+
# 29         1.3万+
# ..           ...
# 196         400+
# 197         400+
# 198        1.6万+
# 199        1.6万+
# 200        1.6万+
# 201        1.6万+
# 202        1.6万+
# 203        1.6万+
# 204         100+
# 205         100+
# 206         100+
# 207         100+
# 208          70+
# 209          60+
# 210          60+
# 211          60+
# 212          60+
# 213          60+
# 214          60+
# 215          60+
# 216          60+
# 217          60+
# 218          60+
# 219          60+
# 220          60+
# 221          60+
# 222          60+
# 223          60+
# 224        1300+
# 225        1300+
#
# [226 rows x 7 columns]

# %% [markdown]
# ### 并行爬取商品评论

# %%
pool = Pool(8)
time1 =time.time()
itemInfo = pool.map(getitemComment,itemidList)
pool.close()
pool.join()
time2 =time.time()
print(str(time2-time1))
# Out:
# 啊呀
# 0/30啊呀
# 0/99啊呀
# 0/44啊呀
# 0/99啊呀
# 0/99啊呀
# 1/30啊呀
# 0/99啊呀
# 0/99啊呀
# 1/44啊呀
# 1/99啊呀
# 0/99啊呀
# 1/99啊呀
# 2/30啊呀啊呀
# 1/99
# 1/99啊呀
# 2/44啊呀
# 1/99啊呀
# 2/99啊呀
# 1/99啊呀
# 2/99啊呀
# 2/99啊呀
# 3/30啊呀
# 3/44啊呀
# 3/99啊呀
# 2/99啊呀
# 2/99啊呀
# 3/99啊呀
# 2/99啊呀
# 4/44啊呀
# 4/30啊呀
# 4/99啊呀
# 3/99啊呀
# 3/99啊呀
# 3/99啊呀
# 4/99啊呀
# 3/99啊呀
# 5/30啊呀
# 5/99啊呀
# 5/44啊呀
# 4/99啊呀
# 5/99啊呀
# 4/99啊呀
# 6/99啊呀
# 6/44啊呀
# 6/30啊呀啊呀
# 4/99
# 4/99啊呀
# 6/99啊呀
# 5/99啊呀
# 5/99啊呀
# 7/99啊呀
# 7/30啊呀
# 7/44啊呀
# 7/99啊呀
# 5/99啊呀
# 5/99啊呀
# 6/99啊呀
# 8/99啊呀
# 6/99啊呀
# 8/30啊呀
# 8/99啊呀
# 8/44啊呀
# 9/99啊呀
# 7/99啊呀
# 6/99啊呀
# 7/99啊呀
# 6/99啊呀
# 9/99啊呀
# 9/30啊呀
# 8/99啊呀
# 10/99啊呀
# 7/99啊呀
# 10/99啊呀
# 8/99啊呀
# 11/99啊呀
# 10/30啊呀啊呀
# 7/99啊呀
# 8/99
# 9/99啊呀
# 11/99啊呀啊呀
# 9/99
# 12/99啊呀
# 11/30啊呀
# 10/99啊呀
# 9/99啊呀
# 8/99啊呀
# 12/99啊呀
# 13/99啊呀
# 11/99啊呀
# 12/30啊呀
# 10/99啊呀
# 10/99啊呀
# 13/99啊呀
# 9/99啊呀
# 13/30啊呀
# 12/99啊呀
# 14/99啊呀
# 11/99啊呀
# 11/99啊呀
# 14/99啊呀
# 14/30啊呀啊呀啊呀
#
# 13/99啊呀
#
# 15/99啊呀
# 15/99啊呀
# 15/30啊呀
# 12/99啊呀
# 14/99啊呀
# 13/99啊呀
# 16/99啊呀
# 11/99啊呀
# 15/99啊呀
# 16/30啊呀
# 17/99啊呀
# 16/99啊呀
# 13/99啊呀
# 14/99啊呀
# 12/99啊呀
# 9/44啊呀
# 18/99啊呀
# 16/99啊呀
# 17/30啊呀啊呀
# 17/99
# 14/99啊呀
# 10/44啊呀
# 13/99啊呀
# 19/99啊呀
# 15/99啊呀
# 17/99啊呀
# 18/99啊呀
# 18/30啊呀
# 20/99啊呀
# 15/99啊呀
# 11/44啊呀
# 14/99啊呀
# 16/99啊呀啊呀
# 21/99
# 18/99啊呀
# 19/99啊呀啊呀
#
# 16/99啊呀
# 17/99啊呀
# 12/44啊呀
# 22/99啊呀
# 19/99啊呀
# 17/99啊呀
# 20/99啊呀
# 20/30啊呀
# 15/99啊呀
# 23/99啊呀
# 18/99啊呀
# 13/44啊呀
# 18/99啊呀
# 21/30啊呀
# 20/99啊呀
# 16/99啊呀
# 21/99啊呀
# 24/99啊呀啊呀
# 22/30
# 14/44啊呀
# 19/99啊呀
# 19/99啊呀
# 21/99啊呀
# 25/99啊呀
# 22/99啊呀
# 23/30啊呀啊呀
# 15/44
# 17/99啊呀
# 20/99啊呀
# 22/99啊呀
# 20/99啊呀
# 26/99啊呀
# 23/99啊呀
# 24/30啊呀
# 16/44啊呀
# 21/99啊呀
# 21/99啊呀
# 23/99啊呀
# 27/99啊呀
# 18/99啊呀
# 25/30啊呀
# 24/99啊呀
# 22/99啊呀
# 17/44啊呀
# 26/30啊呀
# 24/99啊呀
# 22/99啊呀啊呀
# 28/99
# 25/99啊呀
# 19/99啊呀
# 23/99啊呀
# 18/44啊呀
# 27/30啊呀
# 29/99啊呀
# 25/99啊呀啊呀
# 23/99
# 26/99啊呀
# 20/99啊呀
# 24/99啊呀
# 19/44啊呀
# 28/30啊呀
# 30/99啊呀
# 26/99啊呀
# 24/99啊呀
# 27/99啊呀
# 25/99啊呀
# 31/99啊呀
# 29/30啊呀
# 21/99啊呀
# 20/44啊呀
# 25/99啊呀啊呀
# 26/99
# 28/99啊呀啊呀
# 27/99
# 30/30啊呀
# 32/99啊呀
# 21/44啊呀
# 22/99啊呀
# 27/99啊呀
# 26/99啊呀
# 29/99啊呀
# 28/99啊呀
# 22/44啊呀
# 28/99啊呀
# 30/99啊呀
# 27/99啊呀
# 33/99啊呀
# 23/99啊呀
# 0/30啊呀
# 29/99啊呀
# 23/44啊呀
# 34/99啊呀
# 29/99啊呀啊呀
#
# 31/99啊呀啊呀
# 24/44
# 1/30啊呀
# 30/99啊呀
# 24/99啊呀
# 30/99啊呀
# 35/99啊呀
# 29/99啊呀
# 25/44啊呀
# 32/99啊呀
# 2/30啊呀
# 31/99啊呀
# 31/99啊呀
# 30/99啊呀
# 36/99啊呀
# 26/44啊呀
# 25/99啊呀
# 32/99啊呀
# 3/30啊呀
# 33/99啊呀
# 37/99啊呀
# 31/99啊呀
# 32/99啊呀
# 27/44啊呀
# 33/99啊呀
# 34/99啊呀
# 26/99啊呀
# 4/30啊呀
# 28/44啊呀
# 32/99啊呀
# 38/99啊呀
# 35/99啊呀
# 33/99啊呀
# 34/99啊呀
# 5/30啊呀
# 27/99啊呀
# 33/99啊呀
# 36/99啊呀啊呀
# 34/99
# 35/99啊呀
# 39/99啊呀
# 6/30啊呀
# 28/99啊呀
# 34/99啊呀
# 29/44啊呀
# 37/99啊呀
# 35/99啊呀
# 36/99啊呀
# 7/30啊呀啊呀
# 35/99
# 40/99啊呀
# 29/99
# 36/99啊呀
# 8/30啊呀
# 38/99啊呀
# 30/44啊呀
# 37/99啊呀
# 36/99啊呀
# 37/99啊呀
# 41/99啊呀
# 9/30啊呀
# 31/44啊呀
# 39/99啊呀
# 38/99啊呀
# 30/99啊呀
# 37/99啊呀
# 38/99啊呀
# 42/99啊呀
# 10/30啊呀
# 32/44啊呀
# 40/99啊呀
# 39/99啊呀
# 31/99啊呀啊呀
# 39/99
# 38/99啊呀
# 43/99啊呀
# 11/30啊呀
# 啊呀
# 33/44啊呀啊呀
# 40/99
# 40/99啊呀
# 32/99啊呀
# 44/99啊呀
# 39/99啊呀
# 12/30啊呀
# 42/99啊呀
# 34/44啊呀啊呀
#
# 41/99啊呀
# 45/99啊呀
# 41/99啊呀
# 33/99啊呀
# 13/30啊呀
# 35/44啊呀
# 43/99啊呀
# 41/99啊呀啊呀
# 42/99
# 46/99啊呀
# 42/99啊呀
# 14/30啊呀
# 42/99啊呀
# 36/44啊呀
# 43/99啊呀啊呀
# 34/99
# 47/99啊呀
# 44/99啊呀
# 43/99啊呀
# 15/30啊呀
# 37/44啊呀
# 44/99啊呀
# 48/99啊呀
# 43/99啊呀
# 45/99啊呀
# 35/99啊呀
# 45/99啊呀
# 38/44啊呀啊呀
# 44/99啊呀啊呀
# 16/30
#
# 44/99啊呀
# 46/99啊呀
# 36/99啊呀
# 46/99啊呀啊呀
# 45/99
# 39/44啊呀啊呀
# 50/99
# 17/30啊呀
# 45/99啊呀
# 47/99啊呀啊呀
# 40/44
# 47/99啊呀啊呀
# 18/30
# 37/99啊呀
# 46/99啊呀
# 51/99啊呀
# 48/99啊呀
# 46/99啊呀啊呀
#
# 48/99啊呀
# 47/99啊呀
# 19/30啊呀
# 38/99啊呀
# 49/99啊呀
# 52/99啊呀
# 42/44啊呀
# 20/30啊呀
# 49/99啊呀
# 47/99啊呀
# 48/99啊呀
# 39/99啊呀啊呀
# 21/30
# 43/44啊呀
# 50/99啊呀
# 53/99啊呀
# 49/99啊呀
# 48/99
# 50/99啊呀
# 40/99啊呀
# 22/30啊呀
# 44/44啊呀
# 51/99
# 50/99啊呀
# 54/99啊呀
# 49/99啊呀
# 41/99啊呀
# 51/99啊呀
# 23/30啊呀
# 51/99啊呀
# 52/99啊呀
# 42/99啊呀
# 50/99啊呀
# 55/99啊呀
# 24/30啊呀
# 52/99啊呀
# 53/99啊呀
# 51/99啊呀
# 43/99啊呀
# 56/99啊呀
# 0/44啊呀啊呀
# 25/30
# 53/99啊呀
# 54/99啊呀
# 1/44啊呀
# 44/99啊呀
# 26/30啊呀
# 55/99啊呀
# 57/99啊呀
# 52/99啊呀
# 2/44啊呀
# 27/30啊呀啊呀
# 45/99
# 56/99啊呀
# 58/99啊呀
# 3/44啊呀
# 28/30啊呀
# 53/99啊呀
# 57/99啊呀
# 46/99啊呀
# 4/44啊呀
# 59/99啊呀
# 29/30啊呀
# 54/99啊呀
# 5/44啊呀
# 47/99啊呀
# 30/30啊呀
# 60/99啊呀
# 55/99啊呀
# 6/44啊呀
# 48/99啊呀
# 61/99啊呀
# 56/99啊呀
# 52/99啊呀
# 7/44啊呀
# 54/99啊呀
# 0/99啊呀
# 49/99啊呀
# 62/99啊呀
# 57/99啊呀
# 8/44啊呀
# 55/99啊呀
# 1/99啊呀
# 53/99啊呀
# 50/99啊呀
# 2/99啊呀
# 56/99啊呀
# 9/44啊呀
# 63/99啊呀
# 58/99啊呀
# 54/99啊呀
# 3/99啊呀
# 57/99啊呀
# 10/44啊呀
# 64/99啊呀
# 4/99啊呀
# 58/99啊呀
# 51/99啊呀
# 11/44啊呀
# 59/99啊呀
# 55/99啊呀
# 65/99啊呀
# 59/99啊呀
# 5/99啊呀
# 12/44啊呀
# 52/99啊呀
# 60/99啊呀
# 6/99啊呀
# 13/44啊呀
# 66/99啊呀
# 60/99啊呀啊呀
# 53/99
# 56/99啊呀
# 58/99啊呀
# 61/99啊呀
# 7/99啊呀
# 14/44啊呀
# 67/99啊呀
# 59/99啊呀
# 61/99啊呀
# 57/99啊呀
# 62/99啊呀
# 54/99啊呀
# 8/99啊呀
# 15/44啊呀
# 60/99啊呀
# 68/99啊呀啊呀
#
# 62/99啊呀
# 58/99啊呀
# 61/99啊呀
# 16/44啊呀
# 9/99啊呀
# 64/99啊呀
# 69/99啊呀
# 55/99啊呀
# 63/99啊呀
# 10/99啊呀
# 59/99啊呀啊呀
# 65/99
# 啊呀
# 62/99啊呀
# 56/99啊呀
# 11/99啊呀
# 64/99啊呀
# 70/99啊呀
# 60/99啊呀
# 57/99啊呀
# 66/99啊呀
# 63/99啊呀
# 18/44啊呀
# 12/99啊呀
# 65/99啊呀啊呀
#
# 64/99
# 71/99啊呀
# 19/44啊呀
# 58/99啊呀
# 61/99啊呀
# 13/99啊呀
# 66/99啊呀
# 68/99啊呀
# 20/44啊呀
# 72/99啊呀
# 65/99啊呀
# 14/99啊呀
# 59/99啊呀
# 62/99啊呀啊呀
# 69/99
# 67/99啊呀
# 21/44啊呀
# 73/99啊呀
# 66/99啊呀
# 15/99啊呀
# 70/99
# 60/99啊呀
# 68/99啊呀
# 63/99啊呀
# 22/44啊呀
# 16/99啊呀
# 74/99啊呀
# 67/99啊呀
# 71/99啊呀
# 61/99啊呀
# 69/99啊呀
# 17/99啊呀
# 23/44啊呀
# 72/99啊呀啊呀
# 75/99
# 68/99啊呀
# 64/99啊呀
# 62/99啊呀
# 70/99啊呀
# 18/99啊呀啊呀
# 73/99
# 24/44啊呀
# 76/99啊呀
# 69/99啊呀
# 65/99啊呀
# 71/99啊呀
# 19/99啊呀
# 63/99啊呀
# 70/99啊呀
# 74/99啊呀
# 77/99啊呀
# 25/44啊呀
# 66/99啊呀
# 20/99啊呀
# 71/99啊呀啊呀
#
# 64/99啊呀啊呀
# 78/99
# 75/99啊呀
# 26/44啊呀
# 67/99啊呀
# 21/99啊呀
# 72/99啊呀
# 76/99啊呀
# 73/99啊呀
# 79/99啊呀
# 65/99啊呀
# 27/44啊呀
# 68/99啊呀
# 22/99啊呀
# 73/99啊呀
# 77/99啊呀
# 74/99啊呀
# 80/99啊呀
# 23/99啊呀
# 28/44啊呀
# 66/99啊呀
# 74/99啊呀
# 78/99啊呀
# 69/99啊呀
# 75/99啊呀
# 81/99啊呀
# 24/99啊呀
# 75/99啊呀
# 29/44啊呀
# 79/99啊呀
# 76/99啊呀
# 67/99啊呀
# 25/99啊呀
# 70/99啊呀
# 76/99啊呀
# 82/99啊呀
# 80/99啊呀
# 30/44啊呀
# 77/99啊呀
# 26/99啊呀
# 77/99啊呀
# 68/99啊呀
# 71/99啊呀
# 31/44啊呀啊呀
# 81/99
# 83/99啊呀
# 78/99啊呀
# 27/99啊呀
# 78/99啊呀
# 69/99啊呀
# 82/99啊呀
# 32/44啊呀
# 72/99啊呀
# 79/99啊呀
# 84/99啊呀
# 79/99啊呀
# 28/99啊呀
# 83/99啊呀
# 33/44啊呀
# 80/99啊呀
# 70/99啊呀
# 80/99啊呀
# 29/99啊呀
# 85/99啊呀
# 73/99啊呀
# 34/44啊呀
# 30/99啊呀
# 81/99啊呀啊呀
# 81/99
# 84/99啊呀
# 71/99啊呀
# 86/99啊呀
# 74/99啊呀啊呀
# 35/44
# 31/99啊呀
# 82/99啊呀
# 87/99啊呀
# 75/99啊呀
# 72/99啊呀
# 85/99啊呀
# 32/99啊呀
# 啊呀啊呀
# 83/99
# 36/44啊呀
# 88/99啊呀
# 33/99啊呀
# 76/99啊呀
# 73/99啊呀
# 37/44啊呀
# 83/99啊呀
# 84/99啊呀
# 89/99啊呀
# 86/99啊呀
# 34/99啊呀
# 85/99啊呀
# 38/44啊呀
# 74/99啊呀
# 84/99啊呀
# 77/99啊呀
# 87/99啊呀
# 86/99啊呀啊呀
#
# 90/99啊呀
# 75/99啊呀
# 39/44啊呀
# 78/99啊呀
# 88/99啊呀
# 85/99啊呀
# 87/99啊呀
# 36/99啊呀
# 76/99啊呀
# 91/99啊呀
# 40/44啊呀
# 79/99啊呀
# 88/99啊呀
# 89/99啊呀
# 37/99啊呀
# 啊呀
# 41/44啊呀
# 86/99啊呀
# 92/99啊呀
# 80/99啊呀
# 89/99啊呀
# 38/99啊呀
# 90/99啊呀
# 87/99啊呀
# 42/44啊呀
# 78/99啊呀
# 93/99啊呀
# 39/99啊呀
# 90/99啊呀
# 88/99啊呀
# 43/44啊呀
# 91/99啊呀
# 81/99啊呀
# 79/99啊呀
# 啊呀
# 94/99啊呀
# 91/99啊呀
# 44/44啊呀啊呀啊呀
# 89/99
# 92/99
# 41/99啊呀
# 95/99
# 92/99啊呀
# 82/99啊呀
# 42/99啊呀
# 80/99啊呀啊呀
#
# 93/99啊呀
# 93/99啊呀
# 83/99啊呀
# 96/99啊呀
# 43/99啊呀
# 94/99啊呀
# 81/99啊呀
# 91/99啊呀
# 84/99啊呀
# 94/99啊呀
# 44/99啊呀
# 97/99啊呀
# 95/99啊呀
# 92/99啊呀
# 82/99啊呀
# 0/44啊呀
# 85/99啊呀
# 95/99啊呀
# 45/99啊呀
# 96/99啊呀
# 98/99啊呀
# 93/99啊呀
# 1/44啊呀
# 83/99啊呀
# 46/99啊呀
# 86/99啊呀
# 97/99啊呀
# 96/99啊呀
# 94/99啊呀
# 99/99啊呀啊呀
# 47/99
# 84/99啊呀
# 2/44啊呀
# 98/99啊呀
# 95/99啊呀
# 97/99啊呀
# 48/99啊呀
# 87/99啊呀
# 3/44啊呀
# 85/99啊呀
# 99/99啊呀
# 96/99啊呀啊呀
# 49/99
# 98/99啊呀
# 88/99啊呀
# 4/44啊呀
# 0/99啊呀
# 86/99啊呀
# 99/99啊呀
# 97/99啊呀
# 89/99啊呀
# 50/99啊呀
# 5/44啊呀
# 87/99啊呀
# 98/99啊呀
# 1/99啊呀
# 51/99啊呀
# 90/99啊呀
# 0/99啊呀
# 6/44啊呀
# 2/99啊呀
# 0/99啊呀
# 99/99啊呀啊呀啊呀
# 啊呀
#
# 88/99啊呀
# 52/99
# 91/99啊呀
# 3/99啊呀
# 1/99啊呀
# 2/99啊呀
# 8/44啊呀
# 4/99啊呀
# 89/99啊呀
# 2/99啊呀
# 53/99啊呀
# 92/99啊呀
# 9/44啊呀
# 3/99啊呀
# 3/99啊呀
# 0/99啊呀
# 5/99啊呀
# 90/99啊呀
# 54/99啊呀
# 93/99啊呀
# 4/99啊呀
# 4/99啊呀
# 10/44啊呀
# 1/99啊呀
# 6/99啊呀
# 5/99啊呀
# 91/99啊呀
# 5/99啊呀
# 11/44啊呀
# 55/99啊呀
# 94/99啊呀
# 7/99啊呀
# 2/99啊呀
# 6/99啊呀
# 12/44啊呀
# 6/99啊呀
# 56/99啊呀
# 95/99啊呀
# 8/99啊呀
# 3/99啊呀
# 92/99啊呀
# 13/44啊呀
# 7/99啊呀
# 7/99啊呀
# 57/99啊呀
# 4/99啊呀
# 9/99啊呀
# 14/44啊呀
# 93/99啊呀
# 96/99啊呀
# 8/99啊呀
# 8/99啊呀
# 58/99啊呀
# 5/99啊呀
# 10/99啊呀
# 15/44啊呀
# 9/99啊呀
# 94/99啊呀
# 9/99啊呀
# 97/99啊呀
# 6/99啊呀
# 59/99啊呀
# 10/99啊呀
# 10/99啊呀
# 16/44啊呀
# 11/99啊呀
# 7/99啊呀
# 95/99啊呀
# 98/99啊呀
# 60/99啊呀
# 11/99啊呀
# 11/99啊呀
# 17/44啊呀
# 8/99啊呀
# 12/99啊呀
# 9/99啊呀
# 12/99啊呀
# 96/99啊呀
# 99/99啊呀
# 18/44啊呀
# 13/99啊呀
# 12/99啊呀
# 61/99啊呀
# 10/99啊呀
# 13/99啊呀
# 19/44啊呀
# 14/99啊呀
# 13/99啊呀
# 62/99啊呀
# 97/99啊呀
# 11/99啊呀
# 14/99啊呀
# 20/44啊呀
# 14/99啊呀
# 15/99啊呀
# 0/99啊呀
# 98/99啊呀
# 15/99啊呀
# 63/99啊呀
# 12/99啊呀
# 21/44啊呀
# 1/99啊呀
# 16/99啊呀
# 16/99啊呀啊呀
# 99/99
# 13/99啊呀
# 64/99啊呀
# 22/44啊呀
# 15/99啊呀
# 2/99啊呀
# 17/99啊呀
# 17/99啊呀
# 14/99啊呀
# 23/44啊呀
# 65/99啊呀
# 18/99啊呀
# 16/99啊呀
# 3/99啊呀
# 18/99啊呀
# 15/99啊呀
# 0/99啊呀
# 19/99啊呀
# 17/99啊呀
# 24/44啊呀啊呀
#
# 4/99啊呀
# 19/99啊呀
# 20/99啊呀
# 1/99啊呀
# 18/99啊呀
# 16/99啊呀啊呀
# 25/44
# 20/99啊呀
# 5/99啊呀
# 67/99啊呀
# 21/99啊呀
# 2/99啊呀
# 19/99啊呀
# 21/99啊呀啊呀
# 17/99
# 26/44啊呀
# 68/99啊呀
# 22/99啊呀
# 20/99啊呀
# 3/99啊呀
# 22/99啊呀
# 27/44啊呀
# 6/99啊呀
# 18/99啊呀
# 23/99啊呀
# 69/99啊呀
# 21/99啊呀
# 4/99啊呀啊呀
#
# 28/44啊呀啊呀
# 24/99
# 19/99啊呀
# 7/99啊呀
# 22/99啊呀
# 29/44啊呀
# 70/99啊呀
# 25/99啊呀
# 24/99啊呀
# 20/99啊呀
# 8/99
# 5/99啊呀
# 23/99啊呀
# 26/99啊呀
# 30/44啊呀
# 25/99啊呀
# 21/99啊呀
# 9/99啊呀
# 27/99啊呀
# 31/44啊呀
# 6/99啊呀
# 24/99啊呀
# 22/99啊呀
# 26/99啊呀
# 10/99啊呀
# 71/99啊呀
# 28/99啊呀
# 32/44啊呀
# 23/99啊呀
# 7/99啊呀
# 25/99啊呀
# 27/99啊呀
# 11/99啊呀
# 29/99啊呀
# 72/99啊呀
# 33/44啊呀
# 8/99啊呀
# 24/99啊呀
# 28/99啊呀
# 12/99啊呀
# 30/99啊呀
# 26/99啊呀
# 34/44啊呀
# 73/99啊呀
# 9/99啊呀
# 25/99啊呀
# 29/99啊呀
# 13/99啊呀
# 31/99啊呀
# 27/99啊呀
# 35/44啊呀
# 10/99啊呀
# 32/99啊呀
# 26/99啊呀
# 30/99啊呀
# 14/99啊呀
# 74/99啊呀
# 33/99啊呀
# 36/44啊呀
# 11/99啊呀
# 27/99啊呀
# 28/99啊呀
# 31/99啊呀
# 15/99啊呀
# 34/99啊呀
# 37/44啊呀
# 75/99啊呀
# 12/99啊呀啊呀
# 32/99
# 28/99啊呀
# 29/99啊呀
# 35/99啊呀
# 16/99啊呀
# 38/44啊呀
# 76/99啊呀
# 13/99啊呀
# 29/99啊呀
# 36/99啊呀
# 17/99啊呀
# 33/99啊呀
# 30/99啊呀
# 39/44啊呀
# 37/99啊呀
# 30/99啊呀
# 14/99啊呀
# 34/99啊呀
# 18/99啊呀
# 77/99啊呀
# 38/99啊呀
# 40/44啊呀
# 31/99啊呀
# 15/99啊呀
# 35/99啊呀
# 31/99啊呀
# 19/99啊呀
# 41/44啊呀
# 39/99啊呀
# 78/99啊呀
# 32/99啊呀
# 16/99啊呀
# 32/99啊呀
# 36/99啊呀
# 40/99啊呀
# 42/44啊呀
# 20/99啊呀
# 79/99啊呀
# 37/99啊呀
# 17/99啊呀
# 33/99啊呀
# 33/99啊呀
# 啊呀
# 41/99啊呀
# 43/44啊呀
# 80/99啊呀
# 34/99啊呀
# 18/99啊呀
# 38/99啊呀
# 22/99啊呀
# 42/99啊呀
# 44/44啊呀
# 34/99啊呀
# 19/99啊呀
# 35/99啊呀
# 23/99啊呀
# 39/99啊呀
# 43/99啊呀
# 81/99啊呀
# 35/99啊呀
# 36/99啊呀
# 20/99啊呀
# 24/99啊呀
# 44/99啊呀
# 82/99啊呀
# 0/44啊呀
# 40/99啊呀
# 21/99啊呀
# 36/99啊呀
# 37/99啊呀
# 25/99啊呀
# 45/99啊呀
# 1/44啊呀
# 22/99啊呀
# 41/99啊呀
# 83/99啊呀啊呀
# 38/99
# 26/99啊呀
# 37/99啊呀
# 46/99啊呀
# 2/44啊呀
# 23/99啊呀
# 42/99啊呀
# 47/99啊呀
# 27/99啊呀啊呀
# 39/99
# 38/99啊呀
# 84/99啊呀
# 24/99啊呀
# 43/99啊呀
# 3/44啊呀
# 28/99啊呀
# 40/99啊呀
# 39/99啊呀
# 0/99啊呀
# 0/99啊呀
# 0/38啊呀
# 0/99啊呀
# 0/1啊呀
# 0/16啊呀
# 1/99啊呀啊呀
#
# 0/54啊呀
# 1/99啊呀
# 1/99啊呀
# 1/38啊呀啊呀
# 1/16
# 1/1啊呀
# 1/54啊呀
# 1/99啊呀
# 2/99啊呀
# 啊呀
# 2/99啊呀
# 2/38啊呀啊呀
# 2/99
# 2/54啊呀
# 2/16啊呀
# 0/1啊呀
# 1/1啊呀
# 0/99啊呀
# 0/99啊呀
# 0/99啊呀
# 0/33啊呀啊呀
# 0/99
# 0/99啊呀
# 0/99啊呀
# 1/99啊呀
# 1/99啊呀
# 1/99啊呀
# 1/33啊呀
# 0/1啊呀
# 2/99
# 1/99
# 1/99啊呀
# 1/99啊呀
# 2/99啊呀
# 2/99啊呀
# 2/33啊呀
# 啊呀
# 1/1啊呀
# 2/99啊呀
# 2/99啊呀
# 0/79啊呀
# 0/1啊呀
# 0/2啊呀
# 0/34啊呀
# 1/79啊呀
# 0/1啊呀
# 1/1啊呀
# 0/26啊呀
# 0/99啊呀
# 1/2啊呀
# 1/34啊呀
# 2/79啊呀
# 1/1啊呀
# 1/26啊呀
# 2/2啊呀
# 2/34啊呀
# 1/99啊呀
# 0/1啊呀
# 2/26啊呀
# 0/1啊呀
# 1/1啊呀
# 2/99啊呀
# 0/1啊呀
# 1/1啊呀
# 1/1啊呀
# 0/1啊呀
# 0/1啊呀
# 1/1啊呀
# 0/1啊呀
# 1/1啊呀
# 1/1啊呀
# 0/1啊呀
# 1/1啊呀
# 0/1啊呀
# 0/1啊呀
# 1/1啊呀
# 1/1啊呀
# 0/99啊呀
# 1/99啊呀
# 0/1啊呀
# 0/1啊呀
# 2/99啊呀
# 1/1啊呀
# 1/1啊呀
# 0/1啊呀
# 1/1啊呀
# 0/1啊呀
# 1/1啊呀
# 0/1啊呀
# 0/1啊呀
# 1/1啊呀
# 1/1啊呀
# 0/1啊呀
# 0/1啊呀
# 1/1啊呀
# 1/1
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-33-ddf15f412c9d> in <module>()
#       1 pool = Pool(8)
#       2 time1 =time.time()
# ----> 3 itemInfo = pool.map(getitemComment,itemidList)
#       4 pool.close()
#       5 pool.join()
#
# C:\ProgramData\Anaconda3\lib\multiprocessing\pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# C:\ProgramData\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# C:\ProgramData\Anaconda3\lib\multiprocessing\pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception and func is not _helper_reraises_exception:
#
# C:\ProgramData\Anaconda3\lib\multiprocessing\pool.py in mapstar(args)
#      42
#      43 def mapstar(args):
# ---> 44     return list(map(*args))
#      45
#      46 def starmapstar(args):
#
# <ipython-input-32-e70b7e3fe5b6> in getitemComment(itemid)
#       7     for page in range(0,maxPage):
#       8         res = openlink(init_commentUrl.format(itemid,page))
# ----> 9         jc = json.loads(res.text)
#      10         if 'comments' in jc:
#      11             commentlist = jc['comments']
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
